# %% [markdown]
# <a href="https://colab.research.google.com/github/namancode-verse/data-handling/blob/main/06_03_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
meteorites = pd.read_csv('Meteorite_Landings_20240306.csv',nrows=5)
meteorites
# Out:
#        name   id nametype     recclass  mass (g)  fall  year    reclat  \
# 0    Aachen    1    Valid           L5        21  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6       720  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4    107000  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6       780  Fell  1902 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %% [markdown]
# tables and data frames in pandas are almost equivallent.
# . will act like a associative operator,for this function call we are passing two arguements.
# nrow=no of rows
# this is called as parametrized function.

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %% [markdown]
# we are accesing only name coloumn using object meteorites.

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# most of the addreses or array address starts from 0 bec its easy to manage memory.

# %%
import pandas as pd
meteorites = pd.read_csv('Meteorite_Landings_20240306.csv')
meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
import requests
response=requests.get('https://data.nasa.gov/resource/gh4g-9sfh.json',params={'$limit' : 50_000})
if response.ok:
  payload=response.json()
else:
  print(f'Request was not succesful and returned code:{response.status_code}.')
  payload=None

# %% [markdown]
# json file is like structue in c. we can use json file in any type of environment,json file will bring equality. json file will appear like a html file In csv file we can store data in form of comma

# %%
import pandas as pd
df=pd.DataFrame(payload)
df.head(3)
# Out:
#      name id nametype recclass    mass  fall                     year  \
# 0  Aachen  1    Valid       L5      21  Fell  1880-01-01T00:00:00.000
# 1  Aarhus  2    Valid       H6     720  Fell  1951-01-01T00:00:00.000
# 2    Abee  6    Valid      EH4  107000  Fell  1952-01-01T00:00:00.000
#
#       reclat      reclong                                        geolocation  \
# 0  50.775000     6.083330     {'latitude': '50.775', 'longitude': '6.08333'}
# 1  56.183330    10.233330  {'latitude': '56.18333', 'longitude': '10.23333'}
# 2  54.216670  -113.000000    {'latitude': '54.21667', 'longitude': '-113.0'}
#
#   :@computed_region_cbhk_fwbd :@computed_region_nnqa_25f4
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN

# %%
meteorites.shape
# Out:
# (45716, 10)

# %%
df.shape
# Out:
# (45716, 12)

# %%
meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year           float64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %% [markdown]
# equivalent command for this in sql is desc

# %%
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
meteorites[['name' , 'mass (g)']]
# Out:
#              name  mass (g)
# 0          Aachen      21.0
# 1          Aarhus     720.0
# 2            Abee  107000.0
# 3        Acapulco    1914.0
# 4         Achiras     780.0
# ...           ...       ...
# 45711  Zillah 002     172.0
# 45712      Zinder      46.0
# 45713        Zlin       3.3
# 45714   Zubkovsky    2167.0
# 45715  Zulu Queen     200.0
#
# [45716 rows x 2 columns]

# %%
meteorites[100:104]
# Out:
#               name     id nametype       recclass  mass (g)  fall    year  \
# 100         Benton   5026    Valid            LL6    2840.0  Fell  1949.0
# 101         Berduc  48975    Valid             L6     270.0  Fell  2008.0
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell  1924.0
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell  1811.0
#
#        reclat   reclong          GeoLocation
# 100  45.95000 -67.55000      (45.95, -67.55)
# 101 -31.91000 -58.32833  (-31.91, -58.32833)
# 102  11.65000  -3.65000       (11.65, -3.65)
# 103  41.68333  -3.80000     (41.68333, -3.8)

# %% [markdown]
# generalized form of this above command is meteorites[m,n]  (dynamically)

# %%
meteorites.iloc[100:104,[0,3,4,6]]
# Out:
#               name       recclass  mass (g)    year
# 100         Benton            LL6    2840.0  1949.0
# 101         Berduc             L6     270.0  2008.0
# 102         Béréba  Eucrite-mmict   18000.0  1924.0
# 103  Berlanguillas             L6    1440.0  1811.0

# %%
(meteorites['mass (g)'] > 50) & (meteorites.fall == 'Found')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool

# %%
(meteorites['mass (g)'] > 100) & (meteorites.fall == 'Found')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45711     True
# 45712    False
# 45713    False
# 45714     True
# 45715     True
# Length: 45716, dtype: bool
